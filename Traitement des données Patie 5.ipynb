# %% [markdown]
# ### 5.2 Analyse de la variance

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import LabelEncoder

# %%
#afficher fichier tendance_centrale csv
dataI = pd.read_csv("./Data/iris.csv", sep=',')
dataI.head(10)
# Out:
#    longueur_sepal  largeur_sepal  longueur_petal  largeur_petal  espèce
# 0             5.1            3.5             1.4            0.2  setosa
# 1             4.9            3.0             1.4            0.2  setosa
# 2             4.7            3.2             1.3            0.2  setosa
# 3             4.6            3.1             1.5            0.2  setosa
# 4             5.0            3.6             1.4            0.2  setosa
# 5             5.4            3.9             1.7            0.4  setosa
# 6             4.6            3.4             1.4            0.3  setosa
# 7             5.0            3.4             1.5            0.2  setosa
# 8             4.4            2.9             1.4            0.2  setosa
# 9             4.9            3.1             1.5            0.1  setosa

# %%
#Corrélation
dataI.corr()
# Out:
#                 longueur_sepal  largeur_sepal  longueur_petal  largeur_petal
# longueur_sepal        1.000000      -0.117570        0.871754       0.817941
# largeur_sepal        -0.117570       1.000000       -0.428440      -0.366126
# longueur_petal        0.871754      -0.428440        1.000000       0.962865
# largeur_petal         0.817941      -0.366126        0.962865       1.000000

# %% [markdown]
# #### Déterminer s’il existe une relation entre X et Y

# %%
# X = longueur_petal
X=dataI.iloc[:,2].values
# Y = largeur_petal
Y=dataI.iloc[:,3].values

# %%
plt.plot(X,Y,'ob') # ob = type de points "o" ronds, "b" bleus
#Ajouter un titre
plt.title('Relation entre X et Y')
plt.xlabel('longueur_petal')
plt.ylabel('largeur_petal')
plt.show()

# %% [markdown]
# On observe la présence d'une liaison linéaire positive. La corrélation observée est positive. La forme est allongée mais l'étirement est modéré.

# %% [markdown]
# #### 5.3.2. Calcul du coefficient de corrélation de Pearson et interprétation des résultats:

# %%
x=dataI.iloc[:,2:3].values

# %%
LabEnc_y = LabelEncoder()
y=LabEnc_y.fit_transform(Y)

# %%
x = np.array(x)
y = np.array(y)
y = y.reshape((y.shape[0],1))

# %%
longueur_sepal = dataI.iloc[:,0].values
largeur_sepal = dataI.iloc[:,1].values
longueur_petal = dataI.iloc[:,2].values
largeur_petal = dataI.iloc[:,3].values

# %%
pears_long_set, p_val = stats.pearsonr(longueur_sepal, longueur_petal)

# %%
pears_long_set
# Out:
# 0.8717537758865832

# %% [markdown]
# On remarque une corrélation assez forte entre la longeur du sepal et la longueur du pétale.

# %%
stats.pearsonr(longueur_sepal, largeur_petal)
# Out:
# (0.8179411262715757, 2.325498079793167e-37)

# %% [markdown]
# On remarque une corrélation assez forte entre la longeur du sepal et la largeur du pétale.

# %%
sns.pairplot(data=dataI, hue="espèce")
plt.show()
